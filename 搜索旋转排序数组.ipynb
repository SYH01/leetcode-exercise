# %%
from typing import List


class Solution:
    def search(self, nums: List[int], target: int) -> int:
        left,right=0,len(nums)-1;
        L,R=0,len(nums)-1;
        mid=(left+right)//2;
        if target>right and target<left:
            return -1;
        if target==nums[right]:
            return right;
        if target>nums[right]:
            while left<=right:
                if target==nums[mid]:
                    return mid;
                elif target>nums[mid]:
                    if nums[mid]<nums[R]:
                        right=mid-1;
                    else:
                        left=mid+1;
                else:
                    right=mid-1;
                mid=(left+right)//2;
        else:
            while left<=right:
                if target==nums[mid]:
                    return mid;
                elif target<nums[mid]:
                    if nums[mid]>nums[R]:
                        left=mid+1;
                    else:
                        right=mid-1;
                else:
                    left=mid+1;
                mid=(left+right)//2;
        return -1;

# %%
from typing import List


class Solution:
    def search(self, nums: List[int], target: int) -> int:
        left,right=0,len(nums)-1;
        L,R=0,len(nums)-1;
        mid=(left+right)//2;
        if target>right and target<left:
            return -1;
        if target==nums[right]:
            return right;
        if target>nums[right]:
            while left<=right:
                if target==nums[mid]:
                    return mid;
                elif target>nums[mid] and nums[mid]>=nums[R]:
                    left=mid+1;
                else:
                    right=mid-1;
                mid=(left+right)//2;
        else:
            while left<=right:
                if target==nums[mid]:
                    return mid;
                elif target<nums[mid] and nums[mid]<=nums[R]:
                    right=mid-1;
                else:
                    left=mid+1;
                mid=(left+right)//2;
        return -1;

# %%
from typing import List


class Solution:
    def search(self, nums: List[int], target: int) -> int:
        left,right=0,len(nums)-1;
        L,R=0,len(nums)-1;
        mid=(left+right)//2;
        if target>right and target<left:
            return -1;
        if target==nums[right]:
            return right;
        if target>nums[right]:
            while left<=right:
                if target==nums[mid]:
                    return mid;
                
                elif target>nums[mid] and nums[mid]>=nums[R]:
                    left=mid+1;
                else:
                    right=mid-1;
                # elif target>nums[mid]:
                #     if nums[mid]<nums[R]:
                #         right=mid-1;
                #     else:
                #         left=mid+1;
                # else:
                #     right=mid-1;
                mid=(left+right)//2;
        else:
            while left<=right:
                if target==nums[mid]:
                    return mid;
                # elif target<nums[mid]:
                #     if nums[mid]>nums[R]:
                #         left=mid+1;
                #     else:
                #         right=mid-1;
                # else:
                #     left=mid+1;
                elif target<nums[mid] and nums[mid]<=nums[R]:
                    right=mid-1;
                else:
                    left=mid+1;
                mid=(left+right)//2;
        return -1;
